# %%
eggs = 1
spam = eggs * 2
print("Spam:", spam)
print("Spam: {spam}", spam)
# Out:
# Spam: 2
# Spam: {spam} 2

# %%
hex_value=0xFF
print(hex_value)
# Out:
# 255

# %%
hex(255)
# Out:
# '0xff'

# %%
oct(57)
# Out:
# '0o71'

# %%
bin(10)
# Out:
# '0b1010'

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print(type(3.14))
# Out:
# <class 'float'>

# %%
print(type( 10 > 1 ))
# Out:
# <class 'bool'>

# %%
int(3.9)
# Out:
# 3

# %%
float(10)
# Out:
# 10.0

# %%
complex(5)
# Out:
# (5+0j)

# %%
bool(1)
# Out:
# True

# %%
bool(3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
str(1)
# Out:
# '1'

# %%
str(5+0j)
# Out:
# '(5+0j)'

# %%
str(None)
# Out:
# 'None'

# %% [markdown]
# ### String Operations

# %%
my_name = "Peter Miller"
len(my_name)
# Out:
# 12

# %%
my_name = "Peter Miller"
my_name.index("te")
# Out:
# 2

# %%
my_name = "Peter Miller"
my_name.count("e")
# Out:
# 3

# %%
my_name = "Peter Miller"
"My name is " + my_name
# Out:
# 'My name is Peter Miller'

# %%
my_name = "Peter Miller"
my_name[6:8:1]
# Out:
# 'Mi'

# %%
my_string = "My name is Peter Miller"
my_string.split(" ")
# Out:
# ['My', 'name', 'is', 'Peter', 'Miller']

# %%
my_string = " Peter "
my_string.strip(" ")
# Out:
# 'Peter'

# %%
text = "Python"
text = "J" + text[1:]
print(text)
# Out:
# Jython

# %%
text = text2 = "Python"
print(text.replace("Python", "Jython"))
print(text2.replace("P", "J"))
# Out:
# Jython
# Jython

# %% [markdown]
# ## f-strings

# %%
player = "Alex"
goals = 5
msg = f"{player} scored {goals} goals."
print(msg)

# Inside {}, you can even put simple expressions:
print(f"{player} scored {goals * 2} points.")
# Out:
# Alex scored 5 goals.
# Alex scored 10 points.
