# %%
print(type(5))
print(type(3.14))
print(int(3.9))
# Out:
# <class 'int'>
# <class 'float'>
# 3

# %%
weight = 73.0
height = 1.82
bmi = weight / (height**2)
print("BMI:", bmi)

# %% [markdown]
# ## String Operations

# %%
my_string = "Python" + " " + "Rocks"
print(my_string)

my_string_len = len(my_string)
print("Length of my_string:", my_string_len)

if "Rocks" in my_string:
    print("'Rocks' is found in my_string")

# %% [markdown]
# ### Typical string methods
#
# upper(), lower(), strip(), replace(), find(), split(), join(), startswith(), endswith(), format()

# %% [markdown]
# ## Listen von Methoden und Attributen
#
# typical list methods and attributes: append(), extend(), insert(), remove(), pop(), clear(), index(), count(), sort(), reverse()
#
# list1 = [3, 1, 4, 1, 5, 9]
# list2 = [2, 7, 1, 8, 2, 8]
# list3 = liste1 + list2
# print("Combined list:", list3)
#
# % reference copy
# list4 = list1
#
# list4 = list1.copy()
# list4 = copy.copy(list1) % import copy
# list4 = copy.deepcopy(list1)
