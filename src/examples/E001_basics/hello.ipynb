# %% [markdown]
# **Hello World Example** for Python course

# %%
# Example Hello World
print("Hello World!")
name = input()
print("Hello " + name)
# Out:
# Hello World!
#  Anke
# Hello Anke

# %% [markdown]
# **Example for Functions**

# %%
name = "Peter"
print("Hello " + name)
# Out:
# Hello Peter
