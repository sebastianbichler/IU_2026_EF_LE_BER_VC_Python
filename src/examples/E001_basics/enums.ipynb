# %%
import enum


class MyEnums(enum.Enum):
    OPTION_A = "MyOptionA"
    OPTION_B = "MyOptionB"
    OPTION_C = "MyOptionC"


# Example usage
def print_enum_options():
    for option in MyEnums:
        print(f"{option.name}: {option.value}")


print_enum_options()
# Out:
# OPTION_A: MyOptionA
# OPTION_B: MyOptionB
# OPTION_C: MyOptionC
